# %%
import sklearn
from sklearn.datasets import load_iris
import numpy as np
from matplotlib import pyplot as plt
import cv2

# %%
irisDataset=load_iris(return_X_y=True)

# %%
len(irisDataset)
# Out:
# 2

# %%
irisDataset[0].shape
# Out:
# (150, 4)

# %%
irisDataset[1].shape
# Out:
# (150,)

# %%
first2Features=irisDataset[0][:,0:2]

# %%
fig=plt.figure()
ax=fig.add_subplot()
ax.scatter(first2Features[:,0],first2Features[:,1],c=irisDataset[1])
ax.set_xlabel("feature 1")
ax.set_ylabel("feature 2")
ax.set_title("Visualization of first two features")
# Out:
# Text(0.5, 1.0, 'Visualization of first two features')

# %%
np.unique(irisDataset[1])
# Out:
# array([0, 1, 2])
